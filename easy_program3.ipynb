# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayushsingh-d993/Python-Workspace/blob/main/easy_program3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Enter a number: "))

square = num * num

# Convert to string to compare last digits
if str(square).endswith(str(num)):
    print(num, "is an Automorphic number")
else:
    print(num, "is NOT an Automorphic number")
# Out:
# Enter a number: 65
# 65 is NOT an Automorphic number
