# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayushsingh-d993/Ayush_Rajput/blob/main/Quiz_Game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Python Quiz***

# %%
questions = [
    {
        "question": "What is the capital of India?",
        "options": ["A. Mumbai", "B. Delhi", "C. Kolkata", "D. Chennai"],
        "answer": "B"
    },
    {
        "question": "Which language is used for Python programming?",
        "options": ["A. HTML", "B. Java", "C. Python", "D. CSS"],
        "answer": "C"
    },
    {
        "question": "How many days are there in a week?",
        "options": ["A. 5", "B. 6", "C. 7", "D. 8"],
        "answer": "C"
    }
]

score = 0

print("🎯 Welcome to the Quiz Game!\n")

for q in questions:
    print(q["question"])

    for option in q["options"]:
        print(option)

    user_answer = input("Enter your answer (A/B/C/D): ").upper()

    if user_answer == q["answer"]:
        print("✅ Correct!\n")
        score += 1
    else:
        print("❌ Wrong answer!\n")

print("Quiz Finished!")
print(f"Your final score is: {score}/{len(questions)}")
# Out:
# 🎯 Welcome to the Quiz Game!
#
# What is the capital of India?
# A. Mumbai
# B. Delhi
# C. Kolkata
# D. Chennai
