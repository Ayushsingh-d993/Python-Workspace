# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayushsingh-d993/Python-Workspace/blob/main/easy_program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = input("Enter a number: ")

# Check palindrome
if num == num[::-1]:
  print("Palindrome Number")
else:
  print("Not a Palindrome Number")
# Out:
# Enter a number: 5454
# Not a Palindrome Number
